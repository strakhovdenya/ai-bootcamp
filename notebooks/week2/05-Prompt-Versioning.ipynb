# %%
import yaml
from jinja2 import Template
from langsmith import Client
import os

# %%
def build_prompt(preprocessed_context, question):

    prompt = f"""
You are a shopping assistant that can answer questions about the products in stock.

You will be given a question and a list of context.

Instructions:
- You need to answer the question based on the provided context only.
- Never use word context and refer to it as the available products.
- As an output you need to provide:

* The answer to the question based on the provided context.
* The list of the IDs of the chunks that were used to answer the question. Only return the ones that are used in the answer.
* Short description (1-2 sentences) of the item based on the description provided in the context.

- The short description should have the name of the item.
- The answer to the question should contain detailed information about the product and returned with detailed specification in bullet points.

Context:
{preprocessed_context}

Question:
{question}
"""

    return prompt

# %%
preprocessed_context = "- a \n- b"
question = "What is a?"

# %%
jinja_template = """
You are a shopping assistant that can answer questions about the products in stock.

You will be given a question and a list of context.

Instructtions:
- You need to answer the question based on the provided context only.
- Never use word context and refer to it as the available products.
- As an output you need to provide:

* The answer to the question based on the provided context.
* The list of the IDs of the chunks that were used to answer the question. Only return the ones that are used in the answer.
* Short description (1-2 sentences) of the item based on the description provided in the context.

- The short description should have the name of the item.
- The answer to the question should contain detailed information about the product and returned with detailed specification in bullet points.

Context:
{{ preprocessed_context }}

Question:
{{ question }}
"""

# %%
template = Template(jinja_template)

# %%
rendered_template = template.render(preprocessed_context=preprocessed_context, question=question)

# %%
def build_prompt_jinja(preprocessed_context, question):

    prompt = """
You are a shopping assistant that can answer questions about the products in stock.

You will be given a question and a list of context.

Instructtions:
- You need to answer the question based on the provided context only.
- Never use word context and refer to it as the available products.
- As an output you need to provide:

* The answer to the question based on the provided context.
* The list of the IDs of the chunks that were used to answer the question. Only return the ones that are used in the answer.
* Short description (1-2 sentences) of the item based on the description provided in the context.

- The short description should have the name of the item.
- The answer to the question should contain detailed information about the product and returned with detailed specification in bullet points.

Context:
{{ preprocessed_context }}

Question:
{{ question }}
"""

    template = Template(prompt)
    rendered_prompt = template.render(
        preprocessed_context=preprocessed_context,
        question=question
    )

    return rendered_prompt

# %%
def prompt_template_config(yaml_file, prompt_key):

    with open(yaml_file, 'r') as file:
        config = yaml.safe_load(file)

    template_content = config['prompts'][prompt_key]

    template = Template(template_content)

    return template

# %%
def build_prompt_jinja(preprocessed_context, question):

    template = prompt_template_config("prompts/retrieval_generation.yaml", "retrieval_generation")

    rendered_prompt = template.render(
        preprocessed_context=preprocessed_context,
        question=question
    )

    return rendered_prompt

# %%
print(build_prompt_jinja(preprocessed_context, question))
# Out:
# You are a shopping assistant that can answer questions about the products in stock.
#
# You will be given a question and a list of context.
#
# Instructtions:
# - You need to answer the question based on the provided context only.
# - Never use word context and refer to it as the available products.
# - As an output you need to provide:
#
# * The answer to the question based on the provided context.
# * The list of the IDs of the chunks that were used to answer the question. Only return the ones that are used in the answer.
# * Short description (1-2 sentences) of the item based on the description provided in the context.
#
# - The short description should have the name of the item.
# - The answer to the question should contain detailed information about the product and returned with detailed specification in bullet points.
#
# Context:
# - a
# - b
#
# Question:
# What is a?

# %% [markdown]
# ### Prompt Registries (Alternative to Git)

# %%
ls_client = Client()

# %%
prompt = ls_client.pull_prompt(
    "denysstrakhov/retrieval-generation",
    include_model=True
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\utils.py:181, in raise_for_status_with_text(response)
#     180 try:
# --> 181     response.raise_for_status()
#     182 except requests.HTTPError as e:
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\requests\models.py:1028, in Response.raise_for_status(self)
#    1027 if http_error_msg:
# -> 1028     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.smith.langchain.com/commits/denysstrakhov/retrieval-generation/latest?include_model=true
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:1666, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1664                 retry_after = retry_after * 2**idx + random.random()
#    1665                 time.sleep(retry_after)
# -> 1666             except retry_on_:
#    1667                 # Handle other exceptions more immediately
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\utils.py:183, in raise_for_status_with_text(response)
#     182 except requests.HTTPError as e:
# --> 183     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     184 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 404 Client Error: Not Found for url: https://api.smith.langchain.com/commits/denysstrakhov/retrieval-generation/latest?include_model=true] {"error":"Commit not found"}
#
#
# During handling of the above exception, another exception occurred:
#
# LangSmithNotFoundError                    Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 prompt = ls_client.pull_prompt(
#       2     "denysstrakhov/retrieval-generation",
#       3     include_model=True
#       4 )
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:9082, in Client.pull_prompt(self, prompt_identifier, include_model, secrets, secrets_from_env, skip_cache)
#    9078             [GHSA-c67j-w6g6-q2cm](https://github.com/langchain-ai/langchain/security/advisories/GHSA-c67j-w6g6-q2cm)
#    9079             in the `langchain-core` package which this method (but not the entire
#    9080             langsmith package) depends on.
#    9081         """
# -> 9082         prompt_object = self.pull_prompt_commit(
#    9083             prompt_identifier, include_model=include_model, skip_cache=skip_cache
#    9084         )
#    9085         return _process_prompt_manifest(
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:8967, in Client.pull_prompt_commit(self, prompt_identifier, include_model, skip_cache)
#    8963             if cached is not None:
#    8964                 return cached
#    8965
#    8966         # Cache miss or cache skipped - fetch from API
# -> 8967         result = refresh_func()
#    8968
#    8969         # Store in cache (background thread will handle refresh when stale)
#    8970         if not skip_cache and self._cache is not None:
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:8923, in Client._fetch_prompt_from_api(self, prompt_identifier, include_model)
#    8919         """
#    8920         owner, prompt_name, commit_hash = ls_utils.parse_prompt_identifier(
#    8921             prompt_identifier
#    8922         )
# -> 8923         response = self.request_with_retries(
#    8924             "GET",
#    8925             (
#    8926                 f"/commits/{owner}/{prompt_name}/{commit_hash}"
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:1666, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1662                         retry_after = 30
#    1663                 # Add exponential backoff
#    1664                 retry_after = retry_after * 2**idx + random.random()
#    1665                 time.sleep(retry_after)
# -> 1666             except retry_on_:
#    1667                 # Handle other exceptions more immediately
#    1668                 if idx + 1 == stop_after_attempt:
#    1669                     raise
#
# LangSmithNotFoundError: Resource not found for /commits/denysstrakhov/retrieval-generation/latest?include_model=true. HTTPError('404 Client Error: Not Found for url: https://api.smith.langchain.com/commits/denysstrakhov/retrieval-generation/latest?include_model=true', '{"error":"Commit not found"}\n')

# %%
ls_template = ls_client.pull_prompt("denysstrakhov/retrieval-generation")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\utils.py:181, in raise_for_status_with_text(response)
#     180 try:
# --> 181     response.raise_for_status()
#     182 except requests.HTTPError as e:
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\requests\models.py:1028, in Response.raise_for_status(self)
#    1027 if http_error_msg:
# -> 1028     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.smith.langchain.com/commits/-/retrieval-generation/latest
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:1666, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1664                 retry_after = retry_after * 2**idx + random.random()
#    1665                 time.sleep(retry_after)
# -> 1666             except retry_on_:
#    1667                 # Handle other exceptions more immediately
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\utils.py:183, in raise_for_status_with_text(response)
#     182 except requests.HTTPError as e:
# --> 183     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     184 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 400 Client Error: Bad Request for url: https://api.smith.langchain.com/commits/-/retrieval-generation/latest] {"error":"No prompt owner specified"}
#
#
# During handling of the above exception, another exception occurred:
#
# LangSmithError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 ls_template = ls_client.pull_prompt("retrieval-generation")
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:9082, in Client.pull_prompt(self, prompt_identifier, include_model, secrets, secrets_from_env, skip_cache)
#    9078             [GHSA-c67j-w6g6-q2cm](https://github.com/langchain-ai/langchain/security/advisories/GHSA-c67j-w6g6-q2cm)
#    9079             in the `langchain-core` package which this method (but not the entire
#    9080             langsmith package) depends on.
#    9081         """
# -> 9082         prompt_object = self.pull_prompt_commit(
#    9083             prompt_identifier, include_model=include_model, skip_cache=skip_cache
#    9084         )
#    9085         return _process_prompt_manifest(
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:8967, in Client.pull_prompt_commit(self, prompt_identifier, include_model, skip_cache)
#    8963             if cached is not None:
#    8964                 return cached
#    8965
#    8966         # Cache miss or cache skipped - fetch from API
# -> 8967         result = refresh_func()
#    8968
#    8969         # Store in cache (background thread will handle refresh when stale)
#    8970         if not skip_cache and self._cache is not None:
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:8923, in Client._fetch_prompt_from_api(self, prompt_identifier, include_model)
#    8919         """
#    8920         owner, prompt_name, commit_hash = ls_utils.parse_prompt_identifier(
#    8921             prompt_identifier
#    8922         )
# -> 8923         response = self.request_with_retries(
#    8924             "GET",
#    8925             (
#    8926                 f"/commits/{owner}/{prompt_name}/{commit_hash}"
#
# File D:\projects_py\fastapi\ai-bootcamp\.venv\Lib\site-packages\langsmith\client.py:1666, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1662                         retry_after = 30
#    1663                 # Add exponential backoff
#    1664                 retry_after = retry_after * 2**idx + random.random()
#    1665                 time.sleep(retry_after)
# -> 1666             except retry_on_:
#    1667                 # Handle other exceptions more immediately
#    1668                 if idx + 1 == stop_after_attempt:
#    1669                     raise
#
# LangSmithError: Failed to GET /commits/-/retrieval-generation/latest in LangSmith API. HTTPError('400 Client Error: Bad Request for url: https://api.smith.langchain.com/commits/-/retrieval-generation/latest', '{"error":"No prompt owner specified"}\n')
