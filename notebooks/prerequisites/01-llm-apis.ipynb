# %% [markdown]
# ### Load environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OPENAI Client

# %%
import openai
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words"},
    ],
)
print(response.choices[0].message.content)
# Out:
# lantern quill drift ember marigold glacier prism whisker comet velvet

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=536, prompt_tokens=23, total_tokens=559, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=512, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words"},
    ],reasoning_effort="minimal"
)
print(response.choices[0].message.content)
# Out:
# Here are 10 random words:
#
# 1. willow
# 2. beacon
# 3. marmalade
# 4. quill
# 5. prism
# 6. velvet
# 7. riddle
# 8. harbor
# 9. lantern
# 10. cocoa

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=58, prompt_tokens=23, total_tokens=81, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %% [markdown]
# ### Google genai Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant.", "can you print 10 random words"],
    )

print(response.text)
# Out:
# Here are 10 random words for you:
#
# 1.  **Whisper**
# 2.  **Galaxy**
# 3.  **Coffee**
# 4.  **Mountain**
# 5.  **Breeze**
# 6.  **Curiosity**
# 7.  **Elephant**
# 8.  **Journey**
# 9.  **Sunshine**
# 10. **Laughter**

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

chat_completion = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words"},
    ],
)
print(chat_completion.choices[0].message.content)
# Out:
# 1. Fiddle
# 2. Space
# 3. Helicopter
# 4. Caramel
# 5. Dictionary
# 6. Perfume
# 7. Guitar
# 8. Butterfly
# 9. Snowflake
# 10. Harmonica
